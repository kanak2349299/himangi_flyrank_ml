# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# Unit: 1 row = 1 post
# Time window: Last 90 days of historical data to train, and we predict engagement for the next 24 hours after a post is published.

# %%
import pandas as pd
df = pd.read_csv('../../data/starter.csv')
print("Unit of analysis: 1 row = 1 post")
print("Shape:", df.shape)
print("Date range:", df['created_at'].min(), "to", df['created_at'].max())

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Features: text, author_id, created_at, hashtags, follower_count, avg_past_engagement
# Label: engagement_score_24h = likes + 3*comments + 5*shares
# Context: post_id, author_id, created_at  # for grouping and analysis, not used as features
# Excluded: user_email, ip_address  # PII and privacy risk, not needed for ranking

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# Grain check: 1 row per post?
print("Duplicates:", df.duplicated(subset=['post_id']).sum())

# Counts
print("Total posts:", len(df))
print("Missing values:\n", df.isnull().sum())

# Label distribution
print(df['engagement_score_24h'].describe())

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# Data limits:
# 1. Unbalanced history: Old posts may have more data than new posts, so model might be biased to old content.
# 2. GSC-only early rows: If data is only from Google Search Console, we miss social/direct traffic signals.
# 3. Window overlap: Posts published near the 24h cutoff might have incomplete engagement data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ x] Every section above is filled — markdown thinking AND the code that backs it
# - [ x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ x] No client names, URLs, or private queries anywhere
# - [ x] My claims use careful words: observed, measured, directional, decision-support
# - [ x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
